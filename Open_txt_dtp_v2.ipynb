# %%
import numpy as np
import os
import glob
import pandas as pd

# %%
damage_data = pd.DataFrame({'Source':[], 'Datetime':[], 'Text':[], 'Address':[]})
s_index=0

with open ('D:/Рабочие_документы/Обучение/MFTI_ML_Engineer/NLP_24/Diplom/DTP_Moscow_file.txt', 'r', encoding='utf-8-sig') as nf:#Change file path
    l = nf.readlines()
    if l:
        for i in l:
            i = i.strip()
            if i:
                if i[:8] == "ДТП и ЧП":
                    damage_data.loc[s_index, 'Source'] = str(i.strip().split(',')[0])
                    damage_data.loc[s_index, 'Datetime'] = str(i.strip().split(',')[1])
                    damage_data.loc[s_index, 'Text'] = str(' ')
                elif i[:11] == "Подписаться":
                    continue
                elif i[:8] == "Прислать" or not i:
                    s_index +=1
                else:
                    damage_data.loc[s_index, 'Text'] = damage_data.loc[s_index, 'Text'] + ' ' + str(i) 
                    
#                     s_index +=1
damage_data
# Out:
#                    Source             Datetime  \
# 0    ДТП и ЧП МОСКВА и МО   [01.02.2024 11:05]
# 1    ДТП и ЧП МОСКВА и МО   [01.02.2024 12:51]
# 2    ДТП и ЧП МОСКВА и МО   [01.02.2024 13:36]
# 3    ДТП и ЧП МОСКВА и МО   [01.02.2024 14:14]
# 4    ДТП и ЧП МОСКВА и МО   [01.02.2024 15:43]
# ..                    ...                  ...
# 447  ДТП и ЧП МОСКВА и МО   [13.03.2024 22:58]
# 448  ДТП и ЧП МОСКВА и МО   [14.03.2024 12:17]
# 449  ДТП и ЧП МОСКВА и МО   [14.03.2024 12:17]
# 450  ДТП и ЧП МОСКВА и МО   [14.03.2024 14:18]
# 451  ДТП и ЧП МОСКВА и МО   [14.03.2024 14:29]
#
#                                                   Text  Address
# 0      Москва, ул.Подольских Курсантов 4 Сгорел авт...      NaN
# 1                 Подмосковье, Между Рузой и Можайском      NaN
# 2      Подмосковье, Дмитровский г.о. Трасса А107, д...      NaN
# 3      Москва, ЖК «Загорье» Лифт с девушкой сорвалс...      NaN
# 4      Москва, Ленинский проспект 158 Сгорел автомо...      NaN
# ..                                                 ...      ...
# 447    Доп.Видео (https://t.me/dtp777/21096), Москв...      NaN
# 448    Москва, станция метро «Октябрьское Поле» Тру...      NaN
# 449                                    Пятницкое шоссе      NaN
# 450                              Подмосковье, Подольск      NaN
# 451                              Москва, улица Перерва      NaN
#
# [452 rows x 4 columns]

# %%
damage_data_1 = pd.DataFrame({'Source':[], 'Datetime':[], 'Text':[], 'Address':[]})
s_index=-1

with open ('D:/Рабочие_документы/Обучение/MFTI_ML_Engineer/NLP_24/Diplom/DTP_SPB.txt', 'r', encoding='utf-8-sig') as nf: #Change file path
    l = nf.readlines()
    if l:
        for i in l:
            i = i.strip()
            if i:
                if i[:5] == "ПИТЕР":
                    s_index +=1
                    damage_data_1.loc[s_index, 'Source'] = str(i.strip().split(',')[0])
                    damage_data_1.loc[s_index, 'Datetime'] = str(i.strip().split(',')[1])
                    damage_data_1.loc[s_index, 'Text'] = str(' ')
                #elif i[:11] == "Подписаться":
                    #continue
                #elif i[:8] == "Прислать" or not i:
                    #s_index +=1
                else:
                    damage_data_1.loc[s_index, 'Text'] = damage_data_1.loc[s_index, 'Text'] + ' ' + str(i) 
                    
                    #s_index +=1
damage_data_1
# Out:
#                           Source             Datetime  \
# 0    ПИТЕР | ДТП | ЧП | ОЧЕВИДЕЦ    [01.02.2024 9:44]
# 1    ПИТЕР | ДТП | ЧП | ОЧЕВИДЕЦ    [01.02.2024 9:50]
# 2    ПИТЕР | ДТП | ЧП | ОЧЕВИДЕЦ   [01.02.2024 10:13]
# 3    ПИТЕР | ДТП | ЧП | ОЧЕВИДЕЦ   [01.02.2024 23:40]
# 4    ПИТЕР | ДТП | ЧП | ОЧЕВИДЕЦ    [02.02.2024 1:00]
# ..                           ...                  ...
# 368  ПИТЕР | ДТП | ЧП | ОЧЕВИДЕЦ    [19.03.2024 1:25]
# 369  ПИТЕР | ДТП | ЧП | ОЧЕВИДЕЦ    [19.03.2024 1:34]
# 370  ПИТЕР | ДТП | ЧП | ОЧЕВИДЕЦ    [19.03.2024 6:31]
# 371  ПИТЕР | ДТП | ЧП | ОЧЕВИДЕЦ    [19.03.2024 8:48]
# 372  ПИТЕР | ДТП | ЧП | ОЧЕВИДЕЦ    [19.03.2024 8:48]
#
#                                                   Text  Address
# 0      На Межевом канале неравное противостояние ав...      NaN
# 1      Ледовая обстановка у ТЮЗа⛸️ И нет, это не ка...      NaN
# 2      На Университетской набережной Фольксваген со...      NaN
# 3      Как не надо ездить на эскалаторе Девушка еха...      NaN
# 4      Вчера в  19.30 48-летний водитель автомобиля...      NaN
# ..                                                 ...      ...
# 368    Напротив Академ парка ДТП. Произошло недавно...      NaN
# 369    Три выстрела и контрольный в голову. Убийств...      NaN
# 370    В городе Санкт-Петербурге возбуждено уголовн...      NaN
# 371    Пропали Назарова Екатерина Максимовна, 14 ле...      NaN
# 372    Дтп на внешнем кольце перед съездом на Мурма...      NaN
#
# [373 rows x 4 columns]

# %%
damage_data_2 = pd.DataFrame({'Source':[], 'Datetime':[], 'Text':[], 'Address':[]})
s_index=-1

with open ('D:/Рабочие_документы/Обучение/MFTI_ML_Engineer/NLP_24/Diplom/DTP_Vor.txt', 'r', encoding='utf-8-sig') as nf: #Change file path
    l = nf.readlines()
    if l:
        for i in l:
            i = i.strip()
            if i:
                if i[:8] == "ДТП и ЧП":
                    s_index +=1
                    damage_data_2.loc[s_index, 'Source'] = str(i.strip().split(',')[0])
                    damage_data_2.loc[s_index, 'Datetime'] = str(i.strip().split(',')[1])
                    damage_data_2.loc[s_index, 'Text'] = str(' ')
                #elif i[:11] == "Подписаться":
                    #continue
                #elif i[:8] == "Прислать" or not i:
                    #s_index +=1
                else:
                    damage_data_2.loc[s_index, 'Text'] = damage_data_2.loc[s_index, 'Text'] + ' ' + str(i) 
                    
                    #s_index +=1
damage_data_2
# Out:
#                Source             Datetime  \
# 0    ДТП и ЧП Воронеж   [01.02.2024 10:00]
# 1    ДТП и ЧП Воронеж   [01.02.2024 16:03]
# 2    ДТП и ЧП Воронеж   [01.02.2024 17:03]
# 3    ДТП и ЧП Воронеж   [01.02.2024 18:11]
# 4    ДТП и ЧП Воронеж   [02.02.2024 18:50]
# ..                ...                  ...
# 154  ДТП и ЧП Воронеж   [14.03.2024 14:11]
# 155  ДТП и ЧП Воронеж   [14.03.2024 17:15]
# 156  ДТП и ЧП Воронеж   [14.03.2024 17:16]
# 157  ДТП и ЧП Воронеж   [14.03.2024 20:30]
# 158  ДТП и ЧП Воронеж   [15.03.2024 15:24]
#
#                                                   Text  Address
# 0      Минобороны РФ сообщило о перехвате и уничтож...      NaN
# 1      🚑Двое детей и женщина пострадали в столкнове...      NaN
# 2      😱Мужчина и женщина погибли при пожаре в Ново...      NaN
# 3      👨‍⚖️Жителя Воробьёвского района обвинили в у...      NaN
# 4      🚒Два человека погибли на пожаре в лискинском...      NaN
# ..                                                 ...      ...
# 154    20-летний парень из села Нижний Мамон попал ...      NaN
# 155    На одном из балконов по адресу ул. 25 января...      NaN
# 156    ✈️ Самолет Ан-12 совершил аварийную посадку ...      NaN
# 157    На ост. Минская страшная авария. На месте на...      NaN
# 158    Жидкость зеленого цвета плеснули в урны на д...      NaN
#
# [159 rows x 4 columns]

# %%
damage_data_3 = pd.DataFrame({'Source':[], 'Datetime':[], 'Text':[], 'Address':[]})
s_index=-1

with open ('D:/Рабочие_документы/Обучение/MFTI_ML_Engineer/NLP_24/Diplom/DTP_Rost.txt', 'r', encoding='utf-8-sig') as nf: #Change file path
    l = nf.readlines()
    if l:
        for i in l:
            i = i.strip()
            if i:
                if i[:8] == "ДТП и ЧП":
                    s_index +=1
                    damage_data_3.loc[s_index, 'Source'] = str(i.strip().split(',')[0])
                    damage_data_3.loc[s_index, 'Datetime'] = str(i.strip().split(',')[1])
                    damage_data_3.loc[s_index, 'Text'] = str(' ')
                elif i[:12] == "🔴Подписаться":
                    continue
                #elif i[:8] == "Прислать" or not i:
                    #s_index +=1
                else:
                    damage_data_3.loc[s_index, 'Text'] = damage_data_3.loc[s_index, 'Text'] + ' ' + str(i) 
                    
                    #s_index +=1
damage_data_3
# Out:
#              Source             Datetime  \
# 0   ДТП и ЧП Ростов    [01.03.2024 8:31]
# 1   ДТП и ЧП Ростов   [01.03.2024 15:03]
# 2   ДТП и ЧП Ростов   [01.03.2024 19:54]
# 3   ДТП и ЧП Ростов   [02.03.2024 11:31]
# 4   ДТП и ЧП Ростов   [02.03.2024 13:36]
# ..              ...                  ...
# 75  ДТП и ЧП Ростов   [18.03.2024 17:00]
# 76  ДТП и ЧП Ростов   [18.03.2024 19:36]
# 77  ДТП и ЧП Ростов   [18.03.2024 19:53]
# 78  ДТП и ЧП Ростов   [18.03.2024 19:53]
# 79  ДТП и ЧП Ростов   [18.03.2024 22:15]
#
#                                                  Text  Address
# 0     В Ростове с сегодняшнего дня изменится схема...      NaN
# 1     ❗️ С 1 по 30 марта в связи с предстоящим зак...      NaN
# 2     В Ростовской области 7 и 11 марта изменится ...      NaN
# 3     Когда забыл какой ты большой 😅 Замечено в Та...      NaN
# 4     В Азовском районе на пожаре погибла женщина ...      NaN
# ..                                                ...      ...
# 75    Нам пишут: «Вот так ездят автобусы, поворачи...      NaN
# 76                    ❗️В Азове пожар, пишут очевидцы      NaN
# 77                               Еще фото от очевидца      NaN
# 78           МЧС сообщает, что это плановое выжигание      NaN
# 79    Сегодня на улице Каскадной, мужчину зажало в...      NaN
#
# [80 rows x 4 columns]

# %%
damage_data_4 = pd.DataFrame({'Source':[], 'Datetime':[], 'Text':[], 'Address':[]})
s_index=-1

with open ('D:/Рабочие_документы/Обучение/MFTI_ML_Engineer/NLP_24/Diplom/DTP_Bryansk.txt', 'r', encoding='utf-8-sig') as nf: #Change file path
    l = nf.readlines()
    if l:
        for i in l:
            i = i.strip()
            if i:
                if i[:8] == "Брянск /":
                    s_index +=1
                    #print(s_index)
                    damage_data_4.loc[s_index, 'Source'] = str(i.strip().split(',')[0])
                    damage_data_4.loc[s_index, 'Datetime'] = str(i.strip().split(',')[1])
                    damage_data_4.loc[s_index, 'Text'] = str(' ')
                #elif i[:12] == "🔴Подписаться":
                    #continue
                #elif i[:8] == "Прислать" or not i:
                    #s_index +=1
                else:
                    damage_data_4.loc[s_index, 'Text'] = damage_data_4.loc[s_index, 'Text'] + ' ' + str(i) 
                    
                    #s_index +=1
damage_data_4
# Out:
#                       Source             Datetime  \
# 0    Брянск /новости/ ЧП/ДТП   [01.02.2024 12:00]
# 1    Брянск /новости/ ЧП/ДТП   [01.02.2024 16:16]
# 2    Брянск /новости/ ЧП/ДТП   [01.02.2024 21:27]
# 3    Брянск /новости/ ЧП/ДТП    [02.02.2024 9:43]
# 4    Брянск /новости/ ЧП/ДТП   [02.02.2024 13:24]
# ..                       ...                  ...
# 133  Брянск /новости/ ЧП/ДТП   [16.03.2024 22:32]
# 134  Брянск /новости/ ЧП/ДТП   [17.03.2024 14:26]
# 135  Брянск /новости/ ЧП/ДТП   [18.03.2024 12:05]
# 136  Брянск /новости/ ЧП/ДТП   [18.03.2024 12:33]
# 137  Брянск /новости/ ЧП/ДТП   [18.03.2024 19:36]
#
#                                                   Text  Address
# 0      В Брянске устроят облаву на пьяных водителей...      NaN
# 1      В Брянской области 10 февраля пройдет «Лыжня...      NaN
# 2      ‼️Между 22 съезда КПСС 39 и Орловской. Безым...      NaN
# 3      Матч «Динамо-Брянск» с «Сочи-М» завершился б...      NaN
# 4      Утром 2 февраля в Бежице, на улице Плеханова...      NaN
# ..                                                 ...      ...
# 133    В Брянске засыпали громадную яму, в которую ...      NaN
# 134    Под Клинцами водитель иномарки насмерть сбил...      NaN
# 135    В Любохне 48-летний мужчина погиб в ДТП Серь...      NaN
# 136    🔥Сегодня ночью в Суражском районе произошёл ...      NaN
# 137    Мглинских чиновников заставят отремонтироват...      NaN
#
# [138 rows x 4 columns]

# %%
DS = pd.concat([damage_data, damage_data_1, damage_data_2, damage_data_3, damage_data_4], ignore_index = True)
DS
# Out:
#                        Source             Datetime  \
# 0        ДТП и ЧП МОСКВА и МО   [01.02.2024 11:05]
# 1        ДТП и ЧП МОСКВА и МО   [01.02.2024 12:51]
# 2        ДТП и ЧП МОСКВА и МО   [01.02.2024 13:36]
# 3        ДТП и ЧП МОСКВА и МО   [01.02.2024 14:14]
# 4        ДТП и ЧП МОСКВА и МО   [01.02.2024 15:43]
# ...                       ...                  ...
# 1197  Брянск /новости/ ЧП/ДТП   [16.03.2024 22:32]
# 1198  Брянск /новости/ ЧП/ДТП   [17.03.2024 14:26]
# 1199  Брянск /новости/ ЧП/ДТП   [18.03.2024 12:05]
# 1200  Брянск /новости/ ЧП/ДТП   [18.03.2024 12:33]
# 1201  Брянск /новости/ ЧП/ДТП   [18.03.2024 19:36]
#
#                                                    Text  Address
# 0       Москва, ул.Подольских Курсантов 4 Сгорел авт...      NaN
# 1                  Подмосковье, Между Рузой и Можайском      NaN
# 2       Подмосковье, Дмитровский г.о. Трасса А107, д...      NaN
# 3       Москва, ЖК «Загорье» Лифт с девушкой сорвалс...      NaN
# 4       Москва, Ленинский проспект 158 Сгорел автомо...      NaN
# ...                                                 ...      ...
# 1197    В Брянске засыпали громадную яму, в которую ...      NaN
# 1198    Под Клинцами водитель иномарки насмерть сбил...      NaN
# 1199    В Любохне 48-летний мужчина погиб в ДТП Серь...      NaN
# 1200    🔥Сегодня ночью в Суражском районе произошёл ...      NaN
# 1201    Мглинских чиновников заставят отремонтироват...      NaN
#
# [1202 rows x 4 columns]

# %%
DS.to_csv('D:/Рабочие_документы/Обучение/MFTI_ML_Engineer/NLP_24/Diplom/DTP.csv', encoding='utf-8-sig') #Change file path
